# %%
import cv2
from IPython.display import display,Image
from jetbot import bgr8_to_jpeg

img = cv2.imread("/home/jetbot/g031r066/note_nvidia/road_following/test_np_img.jpg")
Image(bgr8_to_jpeg(img))

# %%
print_img = img[40:, 70:]
Image(bgr8_to_jpeg(print_img))
