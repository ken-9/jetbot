# %% [markdown]
# # ライントレース+物体検知

# %% [markdown]
# ## 物体検知側の下準備

# %%
from jetbot import Camera

camera = Camera.instance(width=300, height=300)  # カメラの起動

# %%
import darknet
import darknet_images
import time
"""
load model description and weights from config files
args:
    config_file (str): path to .cfg model file
    data_file (str): path to .data model file
    weights (str): path to weights
returns:
    network: trained model
    class_names
    class_colors
"""
network, class_names, class_colors = darknet.load_network(
    '/home/jetbot/g031r066/darknet/cfg/yolov4-tiny.cfg',  
    '/home/jetbot/g031r066/darknet/cfg/coco.data', 
    '/home/jetbot/g031r066/darknet/weights/yolov4-tiny.weights'
    )

"""
network, class_names, class_colors = darknet.load_network(
        '/home/jetbot/g031r066/darknet/custom/yolov4-tiny-custom.cfg', 
        '/home/jetbot/g031r066/darknet/custom/custom.data',  
        '/home/jetbot/g031r066/darknet/custom/backup/yolov4-tiny-custom_final.weights'
    )
"""
# Out:
# "\nnetwork, class_names, class_colors = darknet.load_network(\n        '/home/jetbot/g031r066/darknet/custom/yolov4-tiny-custom.cfg', \n        '/home/jetbot/g031r066/darknet/custom/custom.data',  \n        '/home/jetbot/g031r066/darknet/custom/backup/yolov4-tiny-custom_final.weights'\n    )\n"

# %% [markdown]
# ## ライントレース側の下準備

# %%
# インポート
import torchvision
import torch

# 自分で作成したライントレースのモデルを読み込む
model_rf = torchvision.models.resnet18(pretrained=False)
model_rf.fc = torch.nn.Linear(512, 2)
model_rf.load_state_dict(torch.load('/home/jetbot/g031r066/note_nvidia/road_following/best_steering_models/[nvidia_circuit-ver1.2]_res18.pth'))
# Out:
# <All keys matched successfully>

# %%
# GPU側に転送
device = torch.device('cuda')
model_rf = model_rf.to(device)
model_rf = model_rf.eval().half()

# %%
# カメラから読み込む映像への前処理を実装
import torchvision.transforms as transforms
import torch.nn.functional as F
import cv2
import PIL.Image
import numpy as np

mean = torch.Tensor([0.485, 0.456, 0.406]).cuda().half()
std = torch.Tensor([0.229, 0.224, 0.225]).cuda().half()

def preprocess(image):
    image = PIL.Image.fromarray(image)
    image = transforms.functional.to_tensor(image).to(device).half()
    image.sub_(mean[:, None, None]).div_(std[:, None, None])
    return image[None, ...]

# %%
# カメラからの映像をセルの下に出力
from IPython.display import display
import ipywidgets
import traitlets
from jetbot import Camera, bgr8_to_jpeg

# camera = Camera()
# image_widget = ipywidgets.Image()
# traitlets.dlink((camera, 'value'), (image_widget, 'value'), transform=bgr8_to_jpeg)

# display(image_widget)

# %%
# 駆動系周りの準備
from jetbot import Robot

robot = Robot()  # 駆動系を制御できるモジュールのインポート

# 制御するバーの設定
speed_gain_slider = ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.01, description='speed gain')
steering_gain_slider = ipywidgets.FloatSlider(min=0.0, max=1.0, step=0.01, value=0.05, description='steering gain')
steering_dgain_slider = ipywidgets.FloatSlider(min=0.0, max=0.5, step=0.001, value=0.0, description='steering kd')
steering_bias_slider = ipywidgets.FloatSlider(min=-0.3, max=0.3, step=0.01, value=0.0, description='steering bias')

# 描画
display(speed_gain_slider, steering_gain_slider, steering_dgain_slider, steering_bias_slider)

# 自Jetbotにおいては、以下の設定だと良い感じに動く
# speed gain = 0.1 2022/09/09 0.15の方が綺麗
# steering gain = 0.05
# steering kd = 0
# steering gain = 0
# Out:
# FloatSlider(value=0.0, description='speed gain', max=1.0, step=0.01)
# FloatSlider(value=0.05, description='steering gain', max=1.0, step=0.01)
# FloatSlider(value=0.0, description='steering kd', max=0.5, step=0.001)
# FloatSlider(value=0.0, description='steering bias', max=0.3, min=-0.3, step=0.01)

# %%
# 現在の動作を示すバーを描画
x_slider = ipywidgets.FloatSlider(min=-1.0, max=1.0, description='x')
y_slider = ipywidgets.FloatSlider(min=0, max=1.0, orientation='vertical', description='y')
steering_slider = ipywidgets.FloatSlider(min=-1.0, max=1.0, description='steering')
speed_slider = ipywidgets.FloatSlider(min=0, max=1.0, orientation='vertical', description='speed')

display(ipywidgets.HBox([y_slider, speed_slider]))
display(x_slider, steering_slider)
# Out:
# HBox(children=(FloatSlider(value=0.0, description='y', max=1.0, orientation='vertical'), FloatSlider(value=0.0…
# FloatSlider(value=0.0, description='x', max=1.0, min=-1.0)
# FloatSlider(value=0.0, description='steering', max=1.0, min=-1.0)

# %% [markdown]
# ## 本処理

# %%
from jetbot import bgr8_to_jpeg
import time
import queue

q = queue.Queue()  # メインスレッド<->サブスレッド で画像をやり取りするためのキューを作っておく

blocked_widget = ipywidgets.FloatSlider(min=0.0, max=1.0, value=0.0, description='blocked')
image_widget = ipywidgets.Image(format='jpeg', width=300, height=300)
label_widget = ipywidgets.IntText(value=1, description='tracked label')
speed_widget = ipywidgets.FloatSlider(value=0.4, min=0.0, max=1.0, description='speed')
turn_gain_widget = ipywidgets.FloatSlider(value=0.8, min=0.0, max=2.0, description='turn gain')
bbox_widget = ipywidgets.Image(format='jpeg', width=300, height=300)

display(ipywidgets.VBox([
    ipywidgets.HBox([image_widget, blocked_widget,bbox_widget]),
    label_widget,
    speed_widget,
    turn_gain_widget
]))

width = int(image_widget.width)
height = int(image_widget.height)

def detection_center(detection):
    """Computes the center x, y coordinates of the object"""
    bbox = detection['bbox']
    center_x = (bbox[0] + bbox[2]) / 2.0 - 0.5
    center_y = (bbox[1] + bbox[3]) / 2.0 - 0.5
    return (center_x, center_y)
    
def norm(vec):
    """Computes the length of the 2D vector"""
    return np.sqrt(vec[0]**2 + vec[1]**2)

def closest_detection(detections):
    """Finds the detection closest to the image center"""
    closest_detection = None
    for det in detections:
        center = detection_center(det)
        if closest_detection is None:
            closest_detection = det
        elif norm(detection_center(det)) < norm(detection_center(closest_detection)):
            closest_detection = det
    return closest_detection

angle = 0.0
angle_last = 0.0

# ライントレースを実装する関数
def road_following(image):
    global angle, angle_last

    xy = model_rf(preprocess(image)).detach().float().cpu().numpy().flatten()
    x = xy[0]
    y = (0.5 - xy[1]) / 2.0
    
    x_slider.value = x
    y_slider.value = y
    
    speed_slider.value = speed_gain_slider.value
    
    angle = np.arctan2(x, y)
    pid = angle * steering_gain_slider.value + (angle - angle_last) * steering_dgain_slider.value
    angle_last = angle
    
    steering_slider.value = pid + steering_bias_slider.value
    
    robot.left_motor.value = max(min(speed_slider.value + steering_slider.value, 1.0), 0.0)
    robot.right_motor.value = max(min(speed_slider.value - steering_slider.value, 1.0), 0.0)

    return 0

# 物体検知を実装する関数
def object_detection(snapshot):
    #snapshot = camera.value.copy()
    #images = darknet_images.load_images(snappshot)
    
    #image_name = images[0]
    prev_time = time.time()
    thresh = .30
    image, detections = darknet_images.image_detection(snapshot, network, class_names, class_colors, thresh)
    
    darknet.print_detections(detections, True)  # True: 各物体の座標・幅・高さを表示
    fps = int(1/(time.time() - prev_time))
    print("FPS: {}".format(fps))
    print("Predicted in {} seconds".format((time.time() - prev_time)))
    
    label_list=[]
    confidence_list=[]
    bbox_list=[]
    for label, confidence, bbox in detections: 
        label_list.append(label)
        confidence_list.append(confidence)
        bbox_list.append(bbox)

    print(label_list)   
    print(confidence_list)
    print(*bbox_list,sep='\n')
    
    q.put(image)  # メインスレッドにbboxを描画した画像を送る
    
    if("Traffic light" in label_list):
        # 信号機部分を切り出し
        i=1
        xmin, ymin, xmax, ymax = darknet.bbox2points(bbox_list[i])
        cropped_image = image[ymin+1:ymax-1, xmin+1:xmax-1]  # bboxの枠線が映らないようにちょっと狭めに切り取る
        
        #import numpy as np
        # 1.HSVに変換して白黒でマスク(2値化)
        hsv_cropped_image = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2HSV)
        # 信号機の目:白,それ以外:黒 でマスクする 
        # 彩度(s)・明度(v)で絞り込む. 信号機の目は大体鮮やかなのでそのようになるように指定
        lower = np.array([0, 200,100])           # 抽出する色の下限(h,s,v)
        upper = np.array([150, 255 , 255])        # 抽出する色の上限(h,s,v)
        mask_traffic_light = cv2.inRange(hsv_cropped_image, lower, upper) # inRangeで元画像を２値化
        
        # 1の結果を基に、信号機の目部分の色はそのままに、それ以外を黒でマスク
        target = cv2.bitwise_and(hsv_cropped_image,hsv_cropped_image, mask=mask_traffic_light)
        
        #from ipywidgets import HBox
        """
        HBox([
            ipywidgets.Image(value=cv2.imencode(".jpg", cropped_image, (cv2.IMWRITE_JPEG_QUALITY, 100))[1].tobytes()),
            ipywidgets.Image(value=cv2.imencode(".jpg", hsv_cropped_image, (cv2.IMWRITE_JPEG_QUALITY, 100))[1].tobytes()),
            ipywidgets.Image(value=cv2.imencode(".jpg", mask_traffic_light, (cv2.IMWRITE_JPEG_QUALITY, 100))[1].tobytes()),
            ipywidgets.Image(value=cv2.imencode(".jpg", target, (cv2.IMWRITE_JPEG_QUALITY, 100))[1].tobytes())
        ])
        """
        # 信号機の目以外は黒色(H=0)でマスクしている為、Hの平均値を出しても小さい値にしかならないので意味がない
        # → なのでHのminとmaxを出す(min要らないけど)
        h_min = target.T[0].flatten().min()
        h_max = target.T[0].flatten().max()
        print("h_min: %s" % (str(h_min)))
        print("h_max: %s" % (str(h_max)))
        
        # Hの最大値で判別する
        if(0 <= h_max <= 30):
            robot.stop() # 赤信号なので一時停止
            time.sleep(0.1) 
            print("Traffic_light : red")
        elif(30<h_max and h_max<=150):  # 緑と青は取り敢えず一緒にした
            print("Traffic_light : green")
        else:
            print("Traffic_light : none")
            
    return 0
# Out:
# VBox(children=(HBox(children=(Image(value=b'', format='jpeg', height='300', width='300'), FloatSlider(value=0.…

# %%
import threading
from IPython.display import clear_output
def execute(change):
    # start_time = time.time()
    
    snapshot = change['new']  # 映像読み込み type(snapshot) = numpy.ndarray

    # ライントレースと物体検知のスレッドをそれぞれ作成
    thread_rf = threading.Thread(target = road_following, args=(snapshot,))
    thread_od = threading.Thread(target = object_detection, args=(snapshot,))

    # 各スレッド実行開始
    thread_rf.start()
    thread_od.start()

    # 各スレッド内の処理が終わるまで待つ
    thread_rf.join()
    thread_od.join()

    # 出力されているカメラ映像の更新
    #image_widget.value = bgr8_to_jpeg(snapshot)
    image_widget.value = cv2.imencode(".jpg", snapshot, (cv2.IMWRITE_JPEG_QUALITY, 100))[1].tobytes()
    bbox_widget.value  = cv2.imencode(".jpg", q.get(), (cv2.IMWRITE_JPEG_QUALITY, 100))[1].tobytes()
    
    # finish_time = time.time()
    # excute_time = finish_time - start_time
    # print(excute_time)
   # clear_output(True)
    
execute({'new': camera.value})
camera.observe(execute, names='value')
# Out:
# Objects:
# bottle: 31.85%    (left_x: 208   top_y:  120   width:   110   height:  231)
# bottle: 53.28%    (left_x: 210   top_y:  211   width:   104   height:  256)
# FPS: 1
# Predicted in 0.5196638107299805 seconds
# ['bottle', 'bottle']
# ['31.85', '53.28']
# (208.0537567138672, 119.6723861694336, 109.71839904785156, 231.34703063964844)
# (209.5205078125, 211.4897003173828, 103.58914184570312, 255.91751098632812)
#
# Objects:
# bottle: 30.14%    (left_x: 209   top_y:  119   width:   107   height:  236)
# cup: 32.73%    (left_x: 209   top_y:  214   width:   106   height:  253)
# chair: 35.14%    (left_x: 371   top_y:  246   width:   95   height:  185)
# bottle: 53.49%    (left_x: 209   top_y:  214   width:   106   height:  253)
# FPS: 8
# Predicted in 0.11802220344543457 seconds
# ['bottle', 'cup', 'chair', 'bottle']
# ['30.14', '32.73', '35.14', '53.49']
# (208.7075958251953, 118.74530792236328, 107.13407135009766, 235.86862182617188)
# (209.14776611328125, 213.61883544921875, 105.54763793945312, 253.09645080566406)
# (370.57550048828125, 245.8272705078125, 94.87285614013672, 184.78758239746094)
# (209.14776611328125, 213.61883544921875, 105.54763793945312, 253.09645080566406)
#
# Objects:
# bottle: 32.35%    (left_x: 208   top_y:  119   width:   110   height:  236)
# bottle: 52.86%    (left_x: 210   top_y:  213   width:   105   height:  260)
# FPS: 8
# Predicted in 0.11548376083374023 seconds
# ['bottle', 'bottle']
# ['32.35', '52.86']
# (208.48809814453125, 118.65367889404297, 109.7447509765625, 236.20957946777344)
# (209.83660888671875, 212.681884765625, 105.0567855834961, 260.3140563964844)
#
# Objects:
# bottle: 62.44%    (left_x: 208   top_y:  211   width:   107   height:  257)
# FPS: 4
# Predicted in 0.20289874076843262 seconds
# ['bottle']
# ['62.44']
# (208.37014770507812, 211.3085479736328, 106.93408966064453, 256.618408203125)
#
# Objects:
# bottle: 38.73%    (left_x: 209   top_y:  119   width:   110   height:  230)
# bottle: 61.47%    (left_x: 208   top_y:  215   width:   106   height:  252)
# FPS: 5
# Predicted in 0.1924147605895996 seconds
# ['bottle', 'bottle']
# ['38.73', '61.47']
# (208.5732421875, 118.941650390625, 110.23133850097656, 230.300537109375)
# (208.46144104003906, 214.53150939941406, 105.83325958251953, 252.29345703125)
#
# Objects:
# keyboard: 31.72%    (left_x: 89   top_y:  182   width:   88   height:  53)
# bottle: 37.08%    (left_x: 208   top_y:  120   width:   112   height:  230)
# bottle: 51.6%    (left_x: 209   top_y:  214   width:   109   height:  253)
# FPS: 8
# Predicted in 0.11773538589477539 seconds
# ['keyboard', 'bottle', 'bottle']
# ['31.72', '37.08', '51.6']
# (89.15591430664062, 181.5964813232422, 87.5016860961914, 52.93048858642578)
# (208.30471801757812, 119.57254028320312, 111.5654296875, 229.5958709716797)
# (209.00514221191406, 213.617919921875, 109.17633819580078, 252.5766143798828)
#
# Objects:
# keyboard: 32.32%    (left_x: 90   top_y:  183   width:   86   height:  54)
# bottle: 44.31%    (left_x: 209   top_y:  121   width:   110   height:  234)
# bottle: 64.34%    (left_x: 209   top_y:  211   width:   105   height:  258)
# FPS: 6
# Predicted in 0.15978646278381348 seconds
# ['keyboard', 'bottle', 'bottle']
# ['32.32', '44.31', '64.34']
# (89.94325256347656, 183.0368194580078, 86.10846710205078, 54.16374588012695)
# (209.49655151367188, 120.65409088134766, 110.41841125488281, 233.70770263671875)
# (209.071044921875, 211.3007354736328, 105.18537902832031, 257.7835693359375)
#
# Objects:
# bottle: 54.0%    (left_x: 209   top_y:  214   width:   108   height:  253)
# FPS: 5
# Predicted in 0.16899633407592773 seconds
# ['bottle']
# ['54.0']
# (208.94650268554688, 214.45147705078125, 108.35089874267578, 252.8350372314453)
#
# Objects:
# bottle: 35.06%    (left_x: 209   top_y:  120   width:   109   height:  232)
# bottle: 58.64%    (left_x: 209   top_y:  214   width:   107   height:  250)
# FPS: 6
# Predicted in 0.16574501991271973 seconds
# ['bottle', 'bottle']
# ['35.06', '58.64']
# (208.823486328125, 119.72981262207031, 109.19471740722656, 232.3529052734375)
# (208.984375, 214.102783203125, 107.3879623413086, 250.48509216308594)
#
# Objects:
# bottle: 32.56%    (left_x: 209   top_y:  120   width:   110   height:  235)
# bottle: 54.14%    (left_x: 208   top_y:  214   width:   107   height:  252)
# FPS: 5
# Predicted in 0.16916155815124512 seconds
# ['bottle', 'bottle']
# ['32.56', '54.14']
# (209.0709686279297, 120.37005615234375, 109.70288848876953, 234.75894165039062)
# (208.40640258789062, 213.8932342529297, 106.83938598632812, 251.8927764892578)
#
# Objects:
# bottle: 30.24%    (left_x: 208   top_y:  119   width:   111   height:  233)
# keyboard: 31.65%    (left_x: 90   top_y:  183   width:   85   height:  54)
# bottle: 48.38%    (left_x: 209   top_y:  214   width:   105   height:  257)
# FPS: 5
# Predicted in 0.1749274730682373 seconds
# ['bottle', 'keyboard', 'bottle']
# ['30.24', '31.65', '48.38']
# (208.3171844482422, 119.27432250976562, 111.4149398803711, 233.398681640625)
# (89.77417755126953, 182.64599609375, 85.4297866821289, 54.438758850097656)
# (208.9119110107422, 213.52593994140625, 104.67154693603516, 257.38006591796875)
#
# Objects:
# bottle: 33.54%    (left_x: 209   top_y:  119   width:   110   height:  234)
# bottle: 64.67%    (left_x: 209   top_y:  213   width:   107   height:  255)
# FPS: 9
# Predicted in 0.10161995887756348 seconds
# ['bottle', 'bottle']
# ['33.54', '64.67']
# (208.65281677246094, 119.07804107666016, 109.60165405273438, 233.54669189453125)
# (208.740966796875, 213.27386474609375, 106.51436614990234, 255.0952911376953)
#
# Objects:
# bottle: 32.83%    (left_x: 209   top_y:  119   width:   111   height:  233)
# bottle: 54.46%    (left_x: 209   top_y:  213   width:   108   height:  256)
# FPS: 6
# Predicted in 0.1629798412322998 seconds
# ['bottle', 'bottle']
# ['32.83', '54.46']
# (208.93394470214844, 119.03360748291016, 110.80306243896484, 232.58975219726562)
# (208.91390991210938, 212.68096923828125, 107.657958984375, 256.23223876953125)
#
# Objects:
# bottle: 51.25%    (left_x: 209   top_y:  214   width:   107   height:  255)
# FPS: 5
# Predicted in 0.1723771095275879 seconds
# ['bottle']
# ['51.25']
# (209.0729522705078, 213.88233947753906, 106.70320892333984, 254.9427490234375)
#
# Objects:
# bottle: 30.89%    (left_x: 209   top_y:  120   width:   109   height:  234)
# bottle: 58.83%    (left_x: 209   top_y:  212   width:   106   height:  254)
# FPS: 5
# Predicted in 0.16855430603027344 seconds
# ['bottle', 'bottle']
# ['30.89', '58.83']
# (208.89584350585938, 120.05686950683594, 109.06002807617188, 234.01068115234375)
# (208.91763305664062, 212.25146484375, 106.29499053955078, 254.24391174316406)
#
# Objects:
# bottle: 34.4%    (left_x: 209   top_y:  120   width:   109   height:  233)
# bottle: 52.51%    (left_x: 208   top_y:  214   width:   107   height:  252)
# FPS: 6
# Predicted in 0.15802693367004395 seconds
# ['bottle', 'bottle']
# ['34.4', '52.51']
# (209.1011505126953, 120.06444549560547, 109.30773162841797, 233.2416534423828)
# (208.44839477539062, 214.35821533203125, 107.28900146484375, 251.85281372070312)
#
# Objects:
# bottle: 31.27%    (left_x: 209   top_y:  119   width:   111   height:  231)
# chair: 44.57%    (left_x: 370   top_y:  245   width:   96   height:  182)
# bottle: 49.3%    (left_x: 209   top_y:  213   width:   106   height:  253)
# FPS: 5
# Predicted in 0.17406249046325684 seconds
# ['bottle', 'chair', 'bottle']
# ['31.27', '44.57', '49.3']
# (209.17494201660156, 119.17398834228516, 111.21920776367188, 231.16819763183594)
# (370.0466613769531, 244.74331665039062, 95.9098129272461, 181.6831512451172)
# (209.49490356445312, 212.97784423828125, 106.1187744140625, 253.30917358398438)
#
# Objects:
# cup: 31.06%    (left_x: 209   top_y:  214   width:   107   height:  251)
# bottle: 55.54%    (left_x: 209   top_y:  214   width:   107   height:  251)
# FPS: 10
# Predicted in 0.09608745574951172 seconds
# ['cup', 'bottle']
# ['31.06', '55.54']
# (209.0931396484375, 213.71478271484375, 106.61932373046875, 251.41629028320312)
# (209.0931396484375, 213.71478271484375, 106.61932373046875, 251.41629028320312)
#
# Objects:
# bottle: 62.2%    (left_x: 208   top_y:  214   width:   106   height:  251)
# FPS: 5
# Predicted in 0.1877458095550537 seconds
# ['bottle']
# ['62.2']
# (208.44515991210938, 213.6333770751953, 105.56137084960938, 251.2794189453125)
#
# Objects:
# cup: 31.23%    (left_x: 209   top_y:  212   width:   106   height:  256)
# bottle: 63.58%    (left_x: 209   top_y:  212   width:   106   height:  256)
# FPS: 5
# Predicted in 0.1763312816619873 seconds
# ['cup', 'bottle']
# ['31.23', '63.58']
# (208.5904998779297, 212.1974334716797, 105.73385620117188, 256.0443115234375)
# (208.5904998779297, 212.1974334716797, 105.73385620117188, 256.0443115234375)
#
# Objects:
# bottle: 50.36%    (left_x: 210   top_y:  213   width:   107   height:  255)
# FPS: 6
# Predicted in 0.16618895530700684 seconds
# ['bottle']
# ['50.36']
# (209.7061309814453, 212.65025329589844, 106.6780014038086, 254.8965301513672)
#
# Objects:
# keyboard: 31.8%    (left_x: 89   top_y:  183   width:   88   height:  51)
# chair: 36.63%    (left_x: 370   top_y:  245   width:   95   height:  185)
# bottle: 56.36%    (left_x: 209   top_y:  210   width:   106   height:  264)
# FPS: 10
# Predicted in 0.09290599822998047 seconds
# ['keyboard', 'chair', 'bottle']
# ['31.8', '36.63', '56.36']
# (89.00850677490234, 182.71163940429688, 87.6197280883789, 51.31760787963867)
# (369.6050109863281, 245.37901306152344, 95.14704132080078, 184.53570556640625)
# (209.0938262939453, 210.075439453125, 106.3952865600586, 264.27734375)
#
# Objects:
# keyboard: 30.42%    (left_x: 90   top_y:  182   width:   88   height:  53)
# bottle: 34.09%    (left_x: 208   top_y:  119   width:   110   height:  235)
# bottle: 53.89%    (left_x: 208   top_y:  213   width:   106   height:  256)
# FPS: 6
# Predicted in 0.16292619705200195 seconds
# ['keyboard', 'bottle', 'bottle']
# ['30.42', '34.09', '53.89']
# (89.6460189819336, 182.3290557861328, 88.31758880615234, 53.00847244262695)
# (208.4297332763672, 119.22476959228516, 109.51839447021484, 234.56993103027344)
# (207.83921813964844, 212.83349609375, 105.77770233154297, 256.2000732421875)
#
# Objects:
# bottle: 31.0%    (left_x: 209   top_y:  119   width:   110   height:  233)
# bottle: 51.54%    (left_x: 209   top_y:  212   width:   107   height:  257)
# FPS: 6
# Predicted in 0.15851092338562012 seconds
# ['bottle', 'bottle']
# ['31.0', '51.54']
# (208.97642517089844, 118.55708312988281, 109.65340423583984, 232.61474609375)
# (208.72116088867188, 212.45724487304688, 107.38986206054688, 256.93017578125)
#
# Objects:
# bottle: 33.44%    (left_x: 208   top_y:  120   width:   111   height:  232)
# bottle: 54.1%    (left_x: 209   top_y:  211   width:   107   height:  257)
# FPS: 5
# Predicted in 0.1701197624206543 seconds
# ['bottle', 'bottle']
# ['33.44', '54.1']
# (208.47901916503906, 120.01848602294922, 111.32936096191406, 231.53021240234375)
# (209.0094451904297, 211.37469482421875, 107.24156951904297, 257.0694274902344)
#
# Objects:
# bottle: 31.79%    (left_x: 209   top_y:  120   width:   109   height:  234)
# bottle: 61.28%    (left_x: 209   top_y:  212   width:   105   height:  255)
# FPS: 5
# Predicted in 0.18099308013916016 seconds
# ['bottle', 'bottle']
# ['31.79', '61.28']
# (209.41073608398438, 120.0347900390625, 108.8670654296875, 233.58221435546875)
# (208.95932006835938, 211.73306274414062, 104.93036651611328, 255.27560424804688)
#
# Objects:
# tvmonitor: 33.55%    (left_x: 56   top_y:  85   width:   105   height:  167)
# bottle: 41.71%    (left_x: 209   top_y:  119   width:   110   height:  228)
# bottle: 42.75%    (left_x: 209   top_y:  212   width:   106   height:  256)
# FPS: 5
# Predicted in 0.1703166961669922 seconds
# ['tvmonitor', 'bottle', 'bottle']
# ['33.55', '41.71', '42.75']
# (56.20322799682617, 84.93087768554688, 105.05238342285156, 167.0923614501953)
# (208.86752319335938, 118.74737548828125, 110.42066955566406, 228.4674530029297)
# (208.9273223876953, 211.613037109375, 106.21319580078125, 255.77511596679688)
#
# Objects:
# chair: 31.26%    (left_x: 370   top_y:  245   width:   96   height:  182)
# bottle: 31.78%    (left_x: 209   top_y:  120   width:   108   height:  235)
# bottle: 38.92%    (left_x: 209   top_y:  214   width:   106   height:  252)
# FPS: 6
# Predicted in 0.15929770469665527 seconds
# ['chair', 'bottle', 'bottle']
# ['31.26', '31.78', '38.92']
# (370.15191650390625, 244.88290405273438, 95.58345794677734, 181.98739624023438)
# (209.41331481933594, 120.45613861083984, 108.47596740722656, 234.79579162597656)
# (208.68360900878906, 213.75027465820312, 105.79196166992188, 251.7207489013672)
#
# Objects:
# tvmonitor: 32.91%    (left_x: 55   top_y:  85   width:   107   height:  168)
# bottle: 55.24%    (left_x: 209   top_y:  214   width:   106   height:  253)
# FPS: 6
# Predicted in 0.16135287284851074 seconds
# ['tvmonitor', 'bottle']
# ['32.91', '55.24']
# (54.993080139160156, 84.99490356445312, 107.14971160888672, 167.6719512939453)
# (209.45098876953125, 213.90721130371094, 106.03241729736328, 253.22662353515625)
#
# Objects:
# bottle: 30.1%    (left_x: 209   top_y:  119   width:   110   height:  231)
# chair: 31.05%    (left_x: 370   top_y:  245   width:   95   height:  182)
# bottle: 58.89%    (left_x: 208   top_y:  212   width:   105   height:  261)
# FPS: 6
# Predicted in 0.16103887557983398 seconds
# ['bottle', 'chair', 'bottle']
# ['30.1', '31.05', '58.89']
# (209.0586395263672, 119.35694122314453, 109.98524475097656, 230.72560119628906)
# (370.2256164550781, 245.32791137695312, 95.18397521972656, 182.41453552246094)
# (208.37454223632812, 212.25619506835938, 104.71454620361328, 260.9252624511719)
#
# Objects:
# bottle: 49.32%    (left_x: 210   top_y:  213   width:   105   height:  258)
# FPS: 6
# Predicted in 0.16051125526428223 seconds
# ['bottle']
# ['49.32']
# (209.69517517089844, 212.55897521972656, 105.32601928710938, 258.1965026855469)
#
# Objects:
# tvmonitor: 31.55%    (left_x: 56   top_y:  85   width:   107   height:  168)
# bottle: 59.51%    (left_x: 209   top_y:  212   width:   106   height:  260)
# FPS: 10
# Predicted in 0.09935712814331055 seconds
# ['tvmonitor', 'bottle']
# ['31.55', '59.51']
# (55.65861892700195, 85.2570571899414, 107.37452697753906, 168.3140106201172)
# (208.955078125, 212.43299865722656, 105.5050048828125, 260.44677734375)
#
# Objects:
# bottle: 46.65%    (left_x: 209   top_y:  214   width:   105   height:  258)
# FPS: 6
# Predicted in 0.15897846221923828 seconds
# ['bottle']
# ['46.65']
# (209.2546844482422, 213.58358764648438, 105.15176391601562, 258.2281799316406)
#
# Objects:
# chair: 33.58%    (left_x: 370   top_y:  245   width:   95   height:  183)
# cup: 34.38%    (left_x: 209   top_y:  212   width:   106   height:  258)
# bottle: 48.77%    (left_x: 209   top_y:  212   width:   106   height:  258)
# FPS: 5
# Predicted in 0.1859416961669922 seconds
# ['chair', 'cup', 'bottle']
# ['33.58', '34.38', '48.77']
# (369.79388427734375, 244.83029174804688, 95.16693878173828, 182.72512817382812)
# (209.13717651367188, 211.5715789794922, 106.3828353881836, 257.5694580078125)
# (209.13717651367188, 211.5715789794922, 106.3828353881836, 257.5694580078125)
#
# Objects:
# bottle: 30.18%    (left_x: 209   top_y:  120   width:   110   height:  233)
# tvmonitor: 36.13%    (left_x: 55   top_y:  86   width:   104   height:  170)
# bottle: 65.45%    (left_x: 209   top_y:  214   width:   104   height:  251)
# FPS: 6
# Predicted in 0.16429352760314941 seconds
# ['bottle', 'tvmonitor', 'bottle']
# ['30.18', '36.13', '65.45']
# (208.73934936523438, 119.87603759765625, 109.71866607666016, 233.10108947753906)
# (55.190513610839844, 86.0284423828125, 104.07658386230469, 169.7447052001953)
# (208.65187072753906, 214.3238067626953, 104.4721450805664, 251.19163513183594)
#
# Objects:
# bottle: 30.52%    (left_x: 209   top_y:  119   width:   111   height:  236)
# cup: 36.12%    (left_x: 209   top_y:  213   width:   105   height:  256)
# bottle: 44.57%    (left_x: 209   top_y:  213   width:   105   height:  256)
# FPS: 5
# Predicted in 0.1689310073852539 seconds
# ['bottle', 'cup', 'bottle']
# ['30.52', '36.12', '44.57']
# (208.58680725097656, 119.37776947021484, 110.71439361572266, 236.00125122070312)
# (208.60047912597656, 213.4715118408203, 105.3376693725586, 256.3985595703125)
# (208.60047912597656, 213.4715118408203, 105.3376693725586, 256.3985595703125)
#
# Objects:
# bottle: 51.32%    (left_x: 209   top_y:  213   width:   106   height:  258)
# FPS: 6
# Predicted in 0.16429495811462402 seconds
# ['bottle']
# ['51.32']
# (209.04335021972656, 212.61874389648438, 106.05889892578125, 257.9366149902344)
#
# Objects:
# bottle: 32.85%    (left_x: 209   top_y:  119   width:   109   height:  228)
# bottle: 50.91%    (left_x: 209   top_y:  212   width:   105   height:  260)
# FPS: 6
# Predicted in 0.1624457836151123 seconds
# ['bottle', 'bottle']
# ['32.85', '50.91']
# (208.99244689941406, 118.64997863769531, 109.48893737792969, 227.83453369140625)
# (209.33177185058594, 212.19021606445312, 105.16395568847656, 259.6632995605469)
#
# Objects:
# bottle: 46.0%    (left_x: 209   top_y:  120   width:   111   height:  232)
# bottle: 59.41%    (left_x: 209   top_y:  212   width:   110   height:  259)
# FPS: 6
# Predicted in 0.16642403602600098 seconds
# ['bottle', 'bottle']
# ['46.0', '59.41']
# (208.89524841308594, 119.68122863769531, 111.29985046386719, 232.4966278076172)
# (208.94793701171875, 212.10446166992188, 109.88654327392578, 259.059814453125)
#
# Objects:
# bottle: 57.6%    (left_x: 209   top_y:  210   width:   108   height:  259)
# FPS: 5
# Predicted in 0.17051029205322266 seconds
# ['bottle']
# ['57.6']
# (209.1373748779297, 210.09683227539062, 108.11544799804688, 259.0373229980469)
#
# Objects:
# bottle: 31.33%    (left_x: 209   top_y:  120   width:   112   height:  233)
# keyboard: 35.17%    (left_x: 90   top_y:  182   width:   86   height:  51)
# bottle: 61.12%    (left_x: 209   top_y:  212   width:   108   height:  253)
# FPS: 5
# Predicted in 0.18097639083862305 seconds
# ['bottle', 'keyboard', 'bottle']
# ['31.33', '35.17', '61.12']
# (208.50498962402344, 119.77557373046875, 111.66757202148438, 232.65191650390625)
# (89.54182434082031, 181.89126586914062, 86.19112396240234, 51.12350845336914)
# (208.5492401123047, 212.09335327148438, 108.26617431640625, 252.52536010742188)
#
# Objects:
# keyboard: 31.49%    (left_x: 89   top_y:  183   width:   88   height:  54)
# bottle: 39.33%    (left_x: 209   top_y:  119   width:   109   height:  232)
# bottle: 59.62%    (left_x: 209   top_y:  213   width:   106   height:  255)
# FPS: 5
# Predicted in 0.1696491241455078 seconds
# ['keyboard', 'bottle', 'bottle']
# ['31.49', '39.33', '59.62']
# (88.85350036621094, 182.6631622314453, 87.84614562988281, 54.17701721191406)
# (208.71490478515625, 119.46784973144531, 108.66960906982422, 231.5718231201172)
# (208.815673828125, 213.3099822998047, 105.8807144165039, 254.5913543701172)
#
# Objects:
# cup: 32.17%    (left_x: 209   top_y:  212   width:   105   height:  254)
# bottle: 33.52%    (left_x: 209   top_y:  120   width:   109   height:  231)
# bottle: 46.44%    (left_x: 209   top_y:  212   width:   105   height:  254)
# FPS: 6
# Predicted in 0.15203499794006348 seconds
# ['cup', 'bottle', 'bottle']
# ['32.17', '33.52', '46.44']
# (209.10623168945312, 212.04833984375, 105.38826751708984, 253.98468017578125)
# (208.73861694335938, 119.824462890625, 109.16661834716797, 231.21119689941406)
# (209.10623168945312, 212.04833984375, 105.38826751708984, 253.98468017578125)
#
# Objects:
# bottle: 59.27%    (left_x: 209   top_y:  214   width:   106   height:  253)
# FPS: 6
# Predicted in 0.162445068359375 seconds
# ['bottle']
# ['59.27']
# (208.97984313964844, 213.60755920410156, 106.46565246582031, 253.24346923828125)
#
# Objects:
# bottle: 40.5%    (left_x: 208   top_y:  213   width:   107   height:  259)
# FPS: 6
# Predicted in 0.16068625450134277 seconds
# ['bottle']
# ['40.5']
# (208.29428100585938, 212.9097442626953, 107.10699462890625, 258.5084533691406)
#
# Objects:
# bottle: 50.9%    (left_x: 209   top_y:  213   width:   104   height:  258)
# FPS: 6
# Predicted in 0.16102933883666992 seconds
# ['bottle']
# ['50.9']
# (208.80043029785156, 213.3435821533203, 104.06317901611328, 257.9271545410156)
#
# Objects:
# keyboard: 31.62%    (left_x: 89   top_y:  183   width:   88   height:  50)
# bottle: 44.41%    (left_x: 210   top_y:  215   width:   108   height:  251)
# FPS: 6
# Predicted in 0.15618419647216797 seconds
# ['keyboard', 'bottle']
# ['31.62', '44.41']
# (88.70529174804688, 182.58929443359375, 88.17143249511719, 49.64041519165039)
# (209.66558837890625, 214.62831115722656, 107.95609283447266, 251.0927734375)
#
# Objects:
# bottle: 32.49%    (left_x: 208   top_y:  119   width:   110   height:  234)
# bottle: 52.44%    (left_x: 209   top_y:  213   width:   107   height:  252)
# FPS: 6
# Predicted in 0.1696925163269043 seconds
# ['bottle', 'bottle']
# ['32.49', '52.44']
# (208.46441650390625, 119.00283813476562, 110.1216812133789, 233.74110412597656)
# (208.67237854003906, 213.323974609375, 106.8062973022461, 252.11709594726562)
#
# Objects:
# chair: 30.56%    (left_x: 370   top_y:  245   width:   96   height:  188)
# bottle: 32.72%    (left_x: 209   top_y:  120   width:   110   height:  226)
# bottle: 41.15%    (left_x: 210   top_y:  213   width:   107   height:  256)
# FPS: 8
# Predicted in 0.1145639419555664 seconds
# ['chair', 'bottle', 'bottle']
# ['30.56', '32.72', '41.15']
# (369.7790222167969, 244.95362854003906, 96.10865783691406, 187.55172729492188)
# (208.57647705078125, 119.52823638916016, 110.36600494384766, 226.37110900878906)
# (209.58914184570312, 213.39466857910156, 106.5660171508789, 256.4851379394531)
#
# Objects:
# bottle: 37.67%    (left_x: 209   top_y:  120   width:   110   height:  232)
# bottle: 54.98%    (left_x: 210   top_y:  211   width:   106   height:  256)
# FPS: 6
# Predicted in 0.16044855117797852 seconds
# ['bottle', 'bottle']
# ['37.67', '54.98']
# (208.88526916503906, 120.3301773071289, 109.91777801513672, 231.5099639892578)
# (209.81320190429688, 211.21578979492188, 106.21151733398438, 255.9030303955078)
#
# Objects:
# bottle: 32.41%    (left_x: 209   top_y:  120   width:   111   height:  232)
# chair: 33.05%    (left_x: 370   top_y:  245   width:   96   height:  184)
# bottle: 55.34%    (left_x: 209   top_y:  212   width:   106   height:  257)
# FPS: 5
# Predicted in 0.1712956428527832 seconds
# ['bottle', 'chair', 'bottle']
# ['32.41', '33.05', '55.34']
# (208.66818237304688, 120.13754272460938, 110.95455169677734, 232.33119201660156)
# (369.81964111328125, 245.14373779296875, 96.05674743652344, 184.39466857910156)
# (208.69920349121094, 212.21759033203125, 106.36309051513672, 257.0899963378906)
#
# Objects:
# bottle: 36.19%    (left_x: 209   top_y:  120   width:   109   height:  233)
# bottle: 47.02%    (left_x: 209   top_y:  214   width:   107   height:  253)
# FPS: 5
# Predicted in 0.17745208740234375 seconds
# ['bottle', 'bottle']
# ['36.19', '47.02']
# (208.8365020751953, 120.20891571044922, 108.68171691894531, 233.41542053222656)
# (208.89968872070312, 213.69590759277344, 107.41039276123047, 253.2304229736328)
#
# Objects:
# bottle: 36.25%    (left_x: 209   top_y:  119   width:   110   height:  235)
# bottle: 56.02%    (left_x: 208   top_y:  213   width:   107   height:  254)
# FPS: 5
# Predicted in 0.17708921432495117 seconds
# ['bottle', 'bottle']
# ['36.25', '56.02']
# (209.1023406982422, 119.11701965332031, 109.75762176513672, 235.0666046142578)
# (207.8791961669922, 213.1481170654297, 107.32347869873047, 254.25018310546875)
#
# Objects:
# bottle: 46.05%    (left_x: 209   top_y:  212   width:   107   height:  256)
# FPS: 5
# Predicted in 0.1788032054901123 seconds
# ['bottle']
# ['46.05']
# (209.06268310546875, 211.62997436523438, 107.23798370361328, 256.11212158203125)
#
# Objects:
# bottle: 54.23%    (left_x: 209   top_y:  213   width:   105   height:  257)
# FPS: 6
# Predicted in 0.1491386890411377 seconds
# ['bottle']
# ['54.23']
# (208.62255859375, 213.0125732421875, 105.16983032226562, 256.99261474609375)
#
# Objects:
# bottle: 30.12%    (left_x: 209   top_y:  119   width:   108   height:  234)
# bottle: 49.25%    (left_x: 209   top_y:  213   width:   106   height:  258)
# FPS: 5
# Predicted in 0.19137001037597656 seconds
# ['bottle', 'bottle']
# ['30.12', '49.25']
# (208.92532348632812, 119.22999572753906, 108.10749053955078, 234.1764678955078)
# (209.1975555419922, 213.42416381835938, 106.11708068847656, 257.642333984375)
#
# Objects:
# bottle: 35.73%    (left_x: 209   top_y:  120   width:   111   height:  234)
# chair: 46.09%    (left_x: 371   top_y:  245   width:   95   height:  186)
# bottle: 52.81%    (left_x: 209   top_y:  213   width:   108   height:  256)
# FPS: 5
# Predicted in 0.17735028266906738 seconds
# ['bottle', 'chair', 'bottle']
# ['35.73', '46.09', '52.81']
# (208.7353057861328, 120.21397399902344, 111.10245513916016, 233.5955047607422)
# (370.7308349609375, 245.47601318359375, 95.36822509765625, 186.00360107421875)
# (208.9981689453125, 213.36856079101562, 108.1568603515625, 255.90032958984375)
#
# Objects:
# chair: 34.68%    (left_x: 370   top_y:  245   width:   96   height:  186)
# bottle: 60.83%    (left_x: 208   top_y:  213   width:   107   height:  252)
# FPS: 10
# Predicted in 0.09516263008117676 seconds
# ['chair', 'bottle']
# ['34.68', '60.83']
# (370.184326171875, 245.1453399658203, 96.0738525390625, 185.5733642578125)
# (208.30828857421875, 212.54908752441406, 107.4610595703125, 252.0829620361328)
#
# Objects:
# keyboard: 32.13%    (left_x: 89   top_y:  182   width:   86   height:  52)
# bottle: 51.42%    (left_x: 210   top_y:  215   width:   109   height:  252)
# FPS: 5
# Predicted in 0.16907048225402832 seconds
# ['keyboard', 'bottle']
# ['32.13', '51.42']
# (88.95683288574219, 182.0640106201172, 86.47432708740234, 51.75400161743164)
# (209.66094970703125, 214.7758026123047, 108.72091674804688, 252.3988494873047)
#
# Objects:
# cup: 46.75%    (left_x: 209   top_y:  210   width:   106   height:  262)
# bottle: 50.36%    (left_x: 209   top_y:  210   width:   106   height:  262)
# FPS: 5
# Predicted in 0.17870330810546875 seconds
# ['cup', 'bottle']
# ['46.75', '50.36']
# (209.26303100585938, 210.0913543701172, 106.10047912597656, 261.6196594238281)
# (209.26303100585938, 210.0913543701172, 106.10047912597656, 261.6196594238281)
#
# Objects:
# bottle: 48.84%    (left_x: 208   top_y:  211   width:   107   height:  256)
# FPS: 6
# Predicted in 0.16347026824951172 seconds
# ['bottle']
# ['48.84']
# (207.9939727783203, 211.43685913085938, 107.48660278320312, 256.3379821777344)
#
# Objects:
# bottle: 38.15%    (left_x: 210   top_y:  119   width:   109   height:  229)
# bottle: 53.64%    (left_x: 208   top_y:  212   width:   109   height:  255)
# FPS: 10
# Predicted in 0.09904074668884277 seconds
# ['bottle', 'bottle']
# ['38.15', '53.64']
# (209.70533752441406, 119.42559814453125, 109.0489273071289, 228.90362548828125)
# (208.376220703125, 212.3232421875, 108.55746459960938, 254.82789611816406)
#
# Objects:
# bottle: 41.89%    (left_x: 209   top_y:  212   width:   107   height:  256)
# FPS: 5
# Predicted in 0.19151854515075684 seconds
# ['bottle']
# ['41.89']
# (208.97689819335938, 212.02352905273438, 106.51834869384766, 256.2568359375)
#
# Objects:
# keyboard: 40.14%    (left_x: 88   top_y:  183   width:   89   height:  53)
# tvmonitor: 43.31%    (left_x: 56   top_y:  85   width:   106   height:  168)
# bottle: 56.2%    (left_x: 209   top_y:  213   width:   105   height:  257)
# FPS: 5
# Predicted in 0.17234277725219727 seconds
# ['keyboard', 'tvmonitor', 'bottle']
# ['40.14', '43.31', '56.2']
# (88.23113250732422, 182.97315979003906, 88.72205352783203, 53.32106399536133)
# (56.11867904663086, 84.89456939697266, 106.46502685546875, 168.33619689941406)
# (208.88929748535156, 212.68711853027344, 105.26068878173828, 257.3028564453125)
#
# Objects:
# FPS: 6
# Predicted in 0.16431975364685059 seconds
# []
# []
#
#
# Objects:
# bottle: 64.59%    (left_x: 208   top_y:  211   width:   105   height:  258)
# FPS: 6
# Predicted in 0.16127562522888184 seconds
# ['bottle']
# ['64.59']
# (207.7860565185547, 210.65301513671875, 105.03889465332031, 258.00628662109375)
#
# Objects:
# FPS: 5
# Predicted in 0.16931915283203125 seconds
# []
# []
#
#
# Objects:
# bottle: 60.26%    (left_x: 210   top_y:  212   width:   106   height:  255)
# FPS: 6
# Predicted in 0.16013860702514648 seconds
# ['bottle']
# ['60.26']
# (209.564208984375, 211.99252319335938, 105.75324249267578, 255.12777709960938)
#
# Objects:
# bottle: 35.56%    (left_x: 210   top_y:  119   width:   110   height:  234)
# chair: 37.05%    (left_x: 369   top_y:  244   width:   96   height:  183)
# keyboard: 37.3%    (left_x: 90   top_y:  182   width:   83   height:  54)
# bottle: 55.74%    (left_x: 209   top_y:  213   width:   107   height:  256)
# FPS: 5
# Predicted in 0.1802823543548584 seconds
# ['bottle', 'chair', 'keyboard', 'bottle']
# ['35.56', '37.05', '37.3', '55.74']
# (209.88706970214844, 119.37188720703125, 109.61099243164062, 233.73851013183594)
# (369.1440124511719, 244.08123779296875, 96.48565673828125, 182.79579162597656)
# (90.21931457519531, 182.318603515625, 83.18888092041016, 54.402381896972656)
# (208.71356201171875, 213.16253662109375, 106.95059204101562, 256.48956298828125)
#
# Objects:
# keyboard: 33.23%    (left_x: 91   top_y:  181   width:   85   height:  52)
# bottle: 33.33%    (left_x: 209   top_y:  119   width:   111   height:  235)
# bottle: 59.75%    (left_x: 208   top_y:  215   width:   109   height:  251)
# FPS: 5
# Predicted in 0.17619609832763672 seconds
# ['keyboard', 'bottle', 'bottle']
# ['33.23', '33.33', '59.75']
# (90.67375183105469, 181.49810791015625, 85.05226135253906, 52.08491897583008)
# (209.26988220214844, 118.59002685546875, 110.9178695678711, 234.51539611816406)
# (208.31309509277344, 214.64080810546875, 108.64999389648438, 251.14016723632812)
#
# Objects:
# bottle: 57.64%    (left_x: 209   top_y:  212   width:   106   height:  259)
# FPS: 5
# Predicted in 0.18270301818847656 seconds
# ['bottle']
# ['57.64']
# (208.90008544921875, 211.5081024169922, 105.5987319946289, 258.9371643066406)
#
# Objects:
# keyboard: 38.49%    (left_x: 90   top_y:  182   width:   84   height:  53)
# bottle: 48.98%    (left_x: 210   top_y:  212   width:   105   height:  259)
# FPS: 5
# Predicted in 0.17949724197387695 seconds
# ['keyboard', 'bottle']
# ['38.49', '48.98']
# (89.9663314819336, 182.04522705078125, 84.11043548583984, 53.228538513183594)
# (209.80746459960938, 211.5738983154297, 105.30946350097656, 259.1054382324219)
#
# Objects:
# bottle: 59.54%    (left_x: 209   top_y:  213   width:   107   height:  254)
# FPS: 5
# Predicted in 0.1877303123474121 seconds
# ['bottle']
# ['59.54']
# (209.16012573242188, 212.60443115234375, 106.76634979248047, 254.48916625976562)
#
# Objects:
# bottle: 35.77%    (left_x: 209   top_y:  120   width:   111   height:  236)
# bottle: 58.8%    (left_x: 209   top_y:  212   width:   107   height:  256)
# FPS: 6
# Predicted in 0.16294360160827637 seconds
# ['bottle', 'bottle']
# ['35.77', '58.8']
# (209.10211181640625, 119.52539825439453, 111.43411254882812, 236.09555053710938)
# (208.70462036132812, 212.11721801757812, 106.71411895751953, 256.2988586425781)
#
# Objects:
# bottle: 54.17%    (left_x: 209   top_y:  212   width:   109   height:  253)
# FPS: 5
# Predicted in 0.17337584495544434 seconds
# ['bottle']
# ['54.17']
# (208.8160400390625, 211.79122924804688, 108.71172332763672, 253.1510772705078)
#
# Objects:
# bottle: 33.66%    (left_x: 209   top_y:  119   width:   110   height:  234)
# bottle: 59.05%    (left_x: 209   top_y:  211   width:   106   height:  257)
# FPS: 5
# Predicted in 0.16921162605285645 seconds
# ['bottle', 'bottle']
# ['33.66', '59.05']
# (208.61318969726562, 118.92546081542969, 110.16246032714844, 234.3623046875)
# (208.52938842773438, 211.01126098632812, 105.7355728149414, 257.3741149902344)
#
# Objects:
# tvmonitor: 32.61%    (left_x: 55   top_y:  85   width:   104   height:  170)
# keyboard: 37.32%    (left_x: 90   top_y:  182   width:   85   height:  52)
# bottle: 63.19%    (left_x: 209   top_y:  212   width:   106   height:  255)
# FPS: 5
# Predicted in 0.1835031509399414 seconds
# ['tvmonitor', 'keyboard', 'bottle']
# ['32.61', '37.32', '63.19']
# (55.23960876464844, 85.19349670410156, 104.29460906982422, 170.32489013671875)
# (90.38513946533203, 181.8071746826172, 84.80011749267578, 51.588863372802734)
# (208.9018096923828, 211.98756408691406, 106.12408447265625, 254.5712432861328)
#
# Objects:
# keyboard: 34.98%    (left_x: 90   top_y:  182   width:   85   height:  53)
# bottle: 46.52%    (left_x: 209   top_y:  214   width:   109   height:  254)
# FPS: 6
# Predicted in 0.1609199047088623 seconds
# ['keyboard', 'bottle']
# ['34.98', '46.52']
# (90.35409545898438, 182.25929260253906, 85.16555786132812, 53.19138717651367)
# (208.89224243164062, 213.55496215820312, 109.44415283203125, 253.62283325195312)
#
# Objects:
# chair: 38.45%    (left_x: 369   top_y:  247   width:   97   height:  187)
# keyboard: 44.21%    (left_x: 90   top_y:  182   width:   86   height:  53)
# bottle: 59.57%    (left_x: 208   top_y:  212   width:   107   height:  254)
# FPS: 6
# Predicted in 0.1661968231201172 seconds
# ['chair', 'keyboard', 'bottle']
# ['38.45', '44.21', '59.57']
# (369.46051025390625, 246.54901123046875, 96.92626953125, 186.91900634765625)
# (89.58985137939453, 182.00250244140625, 86.47771453857422, 52.95728302001953)
# (208.31723022460938, 212.35406494140625, 107.26932525634766, 253.9540557861328)
#
# Objects:
# chair: 33.31%    (left_x: 371   top_y:  246   width:   95   height:  181)
# keyboard: 35.65%    (left_x: 90   top_y:  182   width:   87   height:  52)
# bottle: 54.39%    (left_x: 209   top_y:  213   width:   105   height:  253)
# FPS: 6
# Predicted in 0.1654651165008545 seconds
# ['chair', 'keyboard', 'bottle']
# ['33.31', '35.65', '54.39']
# (370.806640625, 245.53814697265625, 95.21019744873047, 180.87661743164062)
# (90.10189056396484, 182.43043518066406, 86.64142608642578, 51.71499252319336)
# (208.65138244628906, 213.46946716308594, 105.13861083984375, 252.8526611328125)
#
# Objects:
# chair: 32.71%    (left_x: 370   top_y:  244   width:   97   height:  184)
# bottle: 56.0%    (left_x: 209   top_y:  212   width:   108   height:  254)
# FPS: 6
# Predicted in 0.16368937492370605 seconds
# ['chair', 'bottle']
# ['32.71', '56.0']
# (369.69610595703125, 244.4546356201172, 96.7576904296875, 184.21046447753906)
# (208.65921020507812, 212.208740234375, 108.4520492553711, 254.36257934570312)
#
# Objects:
# bottle: 53.65%    (left_x: 209   top_y:  213   width:   105   height:  257)
# FPS: 10
# Predicted in 0.10052657127380371 seconds
# ['bottle']
# ['53.65']
# (208.8574981689453, 212.69894409179688, 105.33184051513672, 257.1319580078125)
#
# Objects:
# chair: 30.2%    (left_x: 370   top_y:  246   width:   96   height:  186)
# bottle: 43.22%    (left_x: 208   top_y:  214   width:   109   height:  256)
# bottle: 46.88%    (left_x: 209   top_y:  119   width:   111   height:  232)
# FPS: 5
# Predicted in 0.17099261283874512 seconds
# ['chair', 'bottle', 'bottle']
# ['30.2', '43.22', '46.88']
# (370.0299987792969, 245.93624877929688, 96.06134796142578, 186.22711181640625)
# (207.90444946289062, 213.59007263183594, 108.50253295898438, 256.4477844238281)
# (208.55056762695312, 118.86721801757812, 110.55708312988281, 232.21348571777344)
#
# Objects:
# bottle: 51.55%    (left_x: 209   top_y:  213   width:   107   height:  253)
# FPS: 6
# Predicted in 0.15446257591247559 seconds
# ['bottle']
# ['51.55']
# (208.76414489746094, 213.3161163330078, 106.65879821777344, 252.91043090820312)
#
# Objects:
# chair: 32.19%    (left_x: 370   top_y:  246   width:   97   height:  184)
# tvmonitor: 36.37%    (left_x: 57   top_y:  85   width:   106   height:  165)
# keyboard: 41.43%    (left_x: 90   top_y:  183   width:   87   height:  53)
# bottle: 58.81%    (left_x: 208   top_y:  212   width:   108   height:  256)
# FPS: 5
# Predicted in 0.17819571495056152 seconds
# ['chair', 'tvmonitor', 'keyboard', 'bottle']
# ['32.19', '36.37', '41.43', '58.81']
# (369.9984130859375, 245.7403106689453, 96.62542724609375, 184.4803466796875)
# (56.57250213623047, 85.3966064453125, 106.21541595458984, 165.04959106445312)
# (90.06624603271484, 182.6798095703125, 86.94861602783203, 53.12947463989258)
# (208.29017639160156, 212.4751434326172, 107.57732391357422, 255.89450073242188)
#
# Objects:
# bottle: 70.05%    (left_x: 209   top_y:  212   width:   106   height:  257)
# FPS: 6
# Predicted in 0.16546201705932617 seconds
# ['bottle']
# ['70.05']
# (208.8123779296875, 211.5214080810547, 105.92881774902344, 256.8001708984375)
#
# Objects:
# cup: 39.0%    (left_x: 209   top_y:  213   width:   104   height:  254)
# bottle: 57.72%    (left_x: 209   top_y:  213   width:   104   height:  254)
# FPS: 5
# Predicted in 0.1693117618560791 seconds
# ['cup', 'bottle']
# ['39.0', '57.72']
# (208.8908233642578, 212.82386779785156, 103.92426300048828, 254.1756591796875)
# (208.8908233642578, 212.82386779785156, 103.92426300048828, 254.1756591796875)
#
# Objects:
# bottle: 54.64%    (left_x: 209   top_y:  213   width:   106   height:  256)
# FPS: 6
# Predicted in 0.1626288890838623 seconds
# ['bottle']
# ['54.64']
# (209.35633850097656, 213.22918701171875, 105.70176696777344, 255.9639892578125)
#
# Objects:
# chair: 30.48%    (left_x: 369   top_y:  245   width:   98   height:  183)
# bottle: 31.68%    (left_x: 209   top_y:  119   width:   109   height:  240)
# bottle: 69.0%    (left_x: 209   top_y:  213   width:   106   height:  252)
# FPS: 5
# Predicted in 0.1680889129638672 seconds
# ['chair', 'bottle', 'bottle']
# ['30.48', '31.68', '69.0']
# (369.1366882324219, 244.6309051513672, 98.0602035522461, 183.2992706298828)
# (209.20062255859375, 119.35688781738281, 108.94287872314453, 240.01036071777344)
# (208.71188354492188, 212.54428100585938, 106.26513671875, 251.5130157470703)
#
# Objects:
# chair: 30.22%    (left_x: 370   top_y:  245   width:   96   height:  184)
# bottle: 31.77%    (left_x: 209   top_y:  120   width:   109   height:  234)
# bottle: 60.92%    (left_x: 209   top_y:  215   width:   106   height:  256)
# FPS: 5
# Predicted in 0.1683037281036377 seconds
# ['chair', 'bottle', 'bottle']
# ['30.22', '31.77', '60.92']
# (369.9459228515625, 244.67984008789062, 96.4856948852539, 184.06483459472656)
# (208.5206756591797, 119.78428649902344, 109.3028335571289, 234.02670288085938)
# (209.06692504882812, 214.92242431640625, 106.46098327636719, 255.5506591796875)
#
# Objects:
# chair: 34.0%    (left_x: 369   top_y:  246   width:   97   height:  186)
# bottle: 59.5%    (left_x: 209   top_y:  213   width:   106   height:  255)
# FPS: 5
# Predicted in 0.17084789276123047 seconds
# ['chair', 'bottle']
# ['34.0', '59.5']
# (369.2438659667969, 245.57676696777344, 96.7079849243164, 185.71893310546875)
# (208.59347534179688, 212.87734985351562, 106.4483642578125, 255.06129455566406)
#
# Objects:
# bottle: 58.43%    (left_x: 209   top_y:  213   width:   106   height:  253)
# FPS: 5
# Predicted in 0.17644453048706055 seconds
# ['bottle']
# ['58.43']
# (208.6643524169922, 212.9381103515625, 105.80779266357422, 253.3430633544922)
#
# Objects:
# chair: 42.37%    (left_x: 370   top_y:  244   width:   97   height:  183)
# bottle: 60.84%    (left_x: 209   top_y:  212   width:   106   height:  260)
# FPS: 10
# Predicted in 0.09347224235534668 seconds
# ['chair', 'bottle']
# ['42.37', '60.84']
# (370.0023193359375, 243.65011596679688, 97.0107192993164, 183.1732635498047)
# (209.3933563232422, 211.690673828125, 106.09191131591797, 259.63275146484375)
#
# Objects:
# bottle: 57.96%    (left_x: 210   top_y:  212   width:   105   height:  257)
# FPS: 6
# Predicted in 0.16641569137573242 seconds
# ['bottle']
# ['57.96']
# (209.63619995117188, 212.47955322265625, 105.12358093261719, 256.7702941894531)
#
# Objects:
# bottle: 54.32%    (left_x: 209   top_y:  212   width:   106   height:  257)
# FPS: 6
# Predicted in 0.16325068473815918 seconds
# ['bottle']
# ['54.32']
# (208.50320434570312, 212.1127166748047, 106.46290588378906, 257.08013916015625)
#
# Objects:
# chair: 36.85%    (left_x: 370   top_y:  245   width:   96   height:  184)
# bottle: 62.14%    (left_x: 209   top_y:  211   width:   108   height:  256)
# FPS: 6
# Predicted in 0.16148972511291504 seconds
# ['chair', 'bottle']
# ['36.85', '62.14']
# (369.56396484375, 244.83592224121094, 96.09390258789062, 184.44326782226562)
# (208.5985870361328, 211.2140655517578, 107.50089263916016, 255.78492736816406)
#
# Objects:
# bottle: 54.06%    (left_x: 209   top_y:  212   width:   105   height:  259)
# FPS: 6
# Predicted in 0.16393828392028809 seconds
# ['bottle']
# ['54.06']
# (209.137451171875, 212.2877197265625, 105.22968292236328, 259.1435241699219)
#
# Objects:
# bottle: 63.16%    (left_x: 208   top_y:  213   width:   107   height:  255)
# FPS: 5
# Predicted in 0.16844725608825684 seconds
# ['bottle']
# ['63.16']
# (208.4749298095703, 213.19552612304688, 106.91217041015625, 255.10472106933594)
#
# Objects:
# keyboard: 32.81%    (left_x: 90   top_y:  182   width:   83   height:  52)
# bottle: 37.78%    (left_x: 209   top_y:  121   width:   111   height:  237)
# bottle: 52.09%    (left_x: 209   top_y:  212   width:   106   height:  258)
# FPS: 6
# Predicted in 0.16236019134521484 seconds
# ['keyboard', 'bottle', 'bottle']
# ['32.81', '37.78', '52.09']
# (90.12104034423828, 182.12132263183594, 83.08081817626953, 52.06932830810547)
# (208.6242218017578, 120.55827331542969, 110.5108871459961, 236.98846435546875)
# (208.77017211914062, 212.32347106933594, 106.38128662109375, 257.5565185546875)
#
# Objects:
# cup: 32.67%    (left_x: 209   top_y:  212   width:   105   height:  258)
# bottle: 51.24%    (left_x: 209   top_y:  212   width:   105   height:  258)
# FPS: 5
# Predicted in 0.1756291389465332 seconds
# ['cup', 'bottle']
# ['32.67', '51.24']
# (208.6185302734375, 211.84556579589844, 105.29801940917969, 257.86553955078125)
# (208.6185302734375, 211.84556579589844, 105.29801940917969, 257.86553955078125)
#
# Objects:
# bottle: 34.56%    (left_x: 208   top_y:  119   width:   110   height:  233)
# keyboard: 37.85%    (left_x: 90   top_y:  182   width:   83   height:  50)
# bottle: 48.28%    (left_x: 209   top_y:  213   width:   106   height:  253)
# FPS: 6
# Predicted in 0.1627204418182373 seconds
# ['bottle', 'keyboard', 'bottle']
# ['34.56', '37.85', '48.28']
# (208.27462768554688, 118.78269958496094, 110.23726654052734, 233.45425415039062)
# (90.23112487792969, 181.90513610839844, 83.46825408935547, 50.44573974609375)
# (209.4915771484375, 213.38031005859375, 106.11190795898438, 252.9744873046875)
#
# Objects:
# chair: 36.05%    (left_x: 370   top_y:  245   width:   95   height:  186)
# bottle: 56.47%    (left_x: 209   top_y:  214   width:   106   height:  251)
# FPS: 6
# Predicted in 0.16619110107421875 seconds
# ['chair', 'bottle']
# ['36.05', '56.47']
# (369.7726745605469, 245.37530517578125, 95.09869384765625, 186.31307983398438)
# (208.9251251220703, 213.55462646484375, 106.04597473144531, 251.2719268798828)
#
# Objects:
# bottle: 64.46%    (left_x: 209   top_y:  214   width:   104   height:  254)
# FPS: 6
# Predicted in 0.16014671325683594 seconds
# ['bottle']
# ['64.46']
# (209.39639282226562, 213.51422119140625, 103.79053497314453, 254.3452606201172)
#
# Objects:
# chair: 31.66%    (left_x: 369   top_y:  247   width:   97   height:  186)
# bottle: 36.17%    (left_x: 209   top_y:  118   width:   110   height:  233)
# bottle: 54.25%    (left_x: 209   top_y:  213   width:   107   height:  253)
# FPS: 6
# Predicted in 0.16373014450073242 seconds
# ['chair', 'bottle', 'bottle']
# ['31.66', '36.17', '54.25']
# (369.058349609375, 246.63722229003906, 96.62084197998047, 186.08045959472656)
# (208.67388916015625, 118.35454559326172, 109.77448272705078, 232.86766052246094)
# (209.1841583251953, 213.14065551757812, 107.24867248535156, 252.75894165039062)
#
# Objects:
# chair: 36.72%    (left_x: 370   top_y:  246   width:   96   height:  184)
# bottle: 58.53%    (left_x: 209   top_y:  213   width:   106   height:  252)
# FPS: 6
# Predicted in 0.1603078842163086 seconds
# ['chair', 'bottle']
# ['36.72', '58.53']
# (369.833740234375, 245.77529907226562, 96.33609008789062, 183.60340881347656)
# (208.90444946289062, 212.6353759765625, 106.03726196289062, 251.785888671875)
#
# Objects:
# bottle: 56.62%    (left_x: 208   top_y:  212   width:   106   height:  258)
# FPS: 9
# Predicted in 0.1082465648651123 seconds
# ['bottle']
# ['56.62']
# (208.47869873046875, 212.31954956054688, 105.613037109375, 258.3182067871094)
#
# Objects:
# keyboard: 32.46%    (left_x: 90   top_y:  183   width:   84   height:  53)
# bottle: 55.16%    (left_x: 208   top_y:  213   width:   106   height:  254)
# FPS: 9
# Predicted in 0.10196495056152344 seconds
# ['keyboard', 'bottle']
# ['32.46', '55.16']
# (90.13631439208984, 182.7858123779297, 84.3504867553711, 53.235450744628906)
# (208.44668579101562, 213.2649383544922, 106.02775573730469, 254.08447265625)
#
# Objects:
# bottle: 63.05%    (left_x: 208   top_y:  213   width:   107   height:  256)
# FPS: 9
# Predicted in 0.10678219795227051 seconds
# ['bottle']
# ['63.05']
# (208.138427734375, 212.6100311279297, 107.2182846069336, 256.4107971191406)
#
# Objects:
# bottle: 61.7%    (left_x: 209   top_y:  214   width:   108   height:  252)
# FPS: 6
# Predicted in 0.1614844799041748 seconds
# ['bottle']
# ['61.7']
# (208.71180725097656, 214.21212768554688, 108.0696029663086, 251.95541381835938)
#
# Objects:
# bottle: 55.74%    (left_x: 208   top_y:  213   width:   106   height:  254)
# FPS: 6
# Predicted in 0.1653130054473877 seconds
# ['bottle']
# ['55.74']
# (207.67105102539062, 213.0666961669922, 106.45828247070312, 253.84127807617188)
#
# Objects:
# bottle: 53.29%    (left_x: 216   top_y:  210   width:   104   height:  256)
# FPS: 5
# Predicted in 0.16845297813415527 seconds
# ['bottle']
# ['53.29']
# (215.5120086669922, 210.14772033691406, 103.86691284179688, 255.66744995117188)
#
# Objects:
# bottle: 53.63%    (left_x: 242   top_y:  214   width:   107   height:  222)
# FPS: 6
# Predicted in 0.16079401969909668 seconds
# ['bottle']
# ['53.63']
# (241.9503936767578, 214.3099365234375, 106.59420776367188, 222.1795196533203)
#
# Objects:
# tvmonitor: 48.34%    (left_x: 87   top_y:  83   width:   109   height:  164)
# FPS: 11
# Predicted in 0.08832764625549316 seconds
# ['tvmonitor']
# ['48.34']
# (87.08511352539062, 83.27685546875, 109.12037658691406, 164.27845764160156)
#
# Objects:
# chair: 37.04%    (left_x: 390   top_y:  272   width:   50   height:  210)
# keyboard: 40.27%    (left_x: 141   top_y:  181   width:   85   height:  57)
# cup: 52.39%    (left_x: 281   top_y:  211   width:   110   height:  275)
# bottle: 61.25%    (left_x: 281   top_y:  211   width:   110   height:  275)
# FPS: 5
# Predicted in 0.17060542106628418 seconds
# ['chair', 'keyboard', 'cup', 'bottle']
# ['37.04', '40.27', '52.39', '61.25']
# (389.6045227050781, 271.9732666015625, 50.18157958984375, 210.2852020263672)
# (141.00962829589844, 181.482421875, 85.20301055908203, 56.81538391113281)
# (281.46746826171875, 210.51966857910156, 109.82744598388672, 274.980224609375)
# (281.46746826171875, 210.51966857910156, 109.82744598388672, 274.980224609375)
#
# Objects:
# cup: 45.8%    (left_x: 302   top_y:  209   width:   101   height:  275)
# bottle: 46.7%    (left_x: 302   top_y:  209   width:   101   height:  275)
# tvmonitor: 74.26%    (left_x: 110   top_y:  80   width:   116   height:  155)
# FPS: 10
# Predicted in 0.09977865219116211 seconds
# ['cup', 'bottle', 'tvmonitor']
# ['45.8', '46.7', '74.26']
# (302.4267578125, 209.0901641845703, 100.93595123291016, 274.690673828125)
# (302.4267578125, 209.0901641845703, 100.93595123291016, 274.690673828125)
# (109.97677612304688, 80.08119201660156, 115.94712829589844, 154.56341552734375)
#
# Objects:
# cup: 30.53%    (left_x: 316   top_y:  211   width:   107   height:  267)
# tvmonitor: 89.12%    (left_x: 119   top_y:  80   width:   106   height:  158)
# FPS: 6
# Predicted in 0.15976333618164062 seconds
# ['cup', 'tvmonitor']
# ['30.53', '89.12']
# (316.26348876953125, 210.57437133789062, 107.03473663330078, 266.84271240234375)
# (118.88328552246094, 80.32528686523438, 106.130615234375, 158.3947296142578)
#
# Objects:
# cup: 56.23%    (left_x: 336   top_y:  213   width:   110   height:  271)
# tvmonitor: 81.68%    (left_x: 124   top_y:  82   width:   109   height:  162)
# FPS: 6
# Predicted in 0.15374350547790527 seconds
# ['cup', 'tvmonitor']
# ['56.23', '81.68']
# (335.9906311035156, 213.02828979492188, 110.1223373413086, 271.41583251953125)
# (123.57135009765625, 81.63455200195312, 109.22858428955078, 161.81295776367188)
#
# Objects:
# keyboard: 31.49%    (left_x: 171   top_y:  178   width:   82   height:  57)
# bottle: 33.39%    (left_x: 339   top_y:  179   width:   96   height:  288)
# cup: 36.33%    (left_x: 336   top_y:  211   width:   100   height:  266)
# tvmonitor: 67.22%    (left_x: 124   top_y:  81   width:   110   height:  160)
# FPS: 10
# Predicted in 0.09821724891662598 seconds
# ['keyboard', 'bottle', 'cup', 'tvmonitor']
# ['31.49', '33.39', '36.33', '67.22']
# (170.71615600585938, 178.0000457763672, 81.76144409179688, 56.62506103515625)
# (339.2567138671875, 178.51809692382812, 96.09268951416016, 288.2269287109375)
# (336.21746826171875, 210.9845428466797, 100.10556030273438, 265.63232421875)
# (124.0592041015625, 81.18655395507812, 109.89021301269531, 159.91293334960938)
#
# Objects:
# bottle: 34.9%    (left_x: 337   top_y:  180   width:   104   height:  290)
# cup: 53.94%    (left_x: 335   top_y:  213   width:   108   height:  262)
# tvmonitor: 69.51%    (left_x: 116   top_y:  81   width:   106   height:  158)
# FPS: 5
# Predicted in 0.16916990280151367 seconds
# ['bottle', 'cup', 'tvmonitor']
# ['34.9', '53.94', '69.51']
# (336.74298095703125, 180.0530548095703, 103.5626220703125, 290.13726806640625)
# ...
#
# Objects:
# cup: 35.71%    (left_x: 246   top_y:  210   width:   120   height:  278)
# chair: 42.35%    (left_x: 360   top_y:  234   width:   99   height:  175)
# bottle: 65.11%    (left_x: 246   top_y:  210   width:   120   height:  278)
# FPS: 5
# Predicted in 0.18317770957946777 seconds
# ['cup', 'chair', 'bottle']
# ['35.71', '42.35', '65.11']
# (245.7579345703125, 210.14515686035156, 119.5261459350586, 277.904541015625)
# (360.0587158203125, 233.76351928710938, 99.19670104980469, 174.8348846435547)
# (245.7579345703125, 210.14515686035156, 119.5261459350586, 277.904541015625)
#
# Objects:
# cup: 52.73%    (left_x: 245   top_y:  207   width:   121   height:  272)
# bottle: 54.12%    (left_x: 245   top_y:  207   width:   121   height:  272)
# FPS: 9
# Predicted in 0.10236549377441406 seconds
# ['cup', 'bottle']
# ['52.73', '54.12']
# (245.46160888671875, 207.46243286132812, 121.19400024414062, 271.7933349609375)
# (245.46160888671875, 207.46243286132812, 121.19400024414062, 271.7933349609375)
#
# Objects:
# cup: 36.8%    (left_x: 246   top_y:  209   width:   122   height:  273)
# bottle: 60.04%    (left_x: 246   top_y:  209   width:   122   height:  273)
# FPS: 5
# Predicted in 0.19271206855773926 seconds
# ['cup', 'bottle']
# ['36.8', '60.04']
# (246.27639770507812, 208.83078002929688, 122.46073150634766, 273.4113464355469)
# (246.27639770507812, 208.83078002929688, 122.46073150634766, 273.4113464355469)
#
# Objects:
# bottle: 58.8%    (left_x: 247   top_y:  206   width:   123   height:  273)
# cup: 62.64%    (left_x: 247   top_y:  206   width:   123   height:  273)
# FPS: 4
# Predicted in 0.20521187782287598 seconds
# ['bottle', 'cup']
# ['58.8', '62.64']
# (246.67828369140625, 206.34390258789062, 122.70899963378906, 273.3230285644531)
# (246.67828369140625, 206.34390258789062, 122.70899963378906, 273.3230285644531)
#
# Objects:
# chair: 33.1%    (left_x: 360   top_y:  234   width:   99   height:  177)
# cup: 52.05%    (left_x: 247   top_y:  206   width:   121   height:  275)
# bottle: 53.01%    (left_x: 247   top_y:  206   width:   121   height:  275)
# FPS: 5
# Predicted in 0.19173932075500488 seconds
# ['chair', 'cup', 'bottle']
# ['33.1', '52.05', '53.01']
# (360.34661865234375, 233.96961975097656, 99.34693908691406, 177.1380157470703)
# (246.65016174316406, 205.63571166992188, 120.78742980957031, 275.47174072265625)
# (246.65016174316406, 205.63571166992188, 120.78742980957031, 275.47174072265625)
#
# Objects:
# cup: 59.0%    (left_x: 246   top_y:  209   width:   123   height:  280)
# bottle: 62.42%    (left_x: 246   top_y:  209   width:   123   height:  280)
# FPS: 5
# Predicted in 0.17813611030578613 seconds
# ['cup', 'bottle']
# ['59.0', '62.42']
# (246.3968505859375, 208.58596801757812, 122.78126525878906, 279.5440673828125)
# (246.3968505859375, 208.58596801757812, 122.78126525878906, 279.5440673828125)
#
# Objects:
# cup: 44.57%    (left_x: 245   top_y:  208   width:   120   height:  273)
# chair: 44.87%    (left_x: 360   top_y:  233   width:   98   height:  173)
# bottle: 55.78%    (left_x: 245   top_y:  208   width:   120   height:  273)
# FPS: 10
# Predicted in 0.09882473945617676 seconds
# ['cup', 'chair', 'bottle']
# ['44.57', '44.87', '55.78']
# (245.09268188476562, 208.38363647460938, 120.35063171386719, 273.3947448730469)
# (360.07177734375, 233.2142791748047, 98.24235534667969, 173.18502807617188)
# (245.09268188476562, 208.38363647460938, 120.35063171386719, 273.3947448730469)
#
# Objects:
# chair: 45.67%    (left_x: 361   top_y:  234   width:   99   height:  175)
# bottle: 49.45%    (left_x: 246   top_y:  208   width:   123   height:  280)
# cup: 52.22%    (left_x: 246   top_y:  208   width:   123   height:  280)
# FPS: 5
# Predicted in 0.17389178276062012 seconds
# ['chair', 'bottle', 'cup']
# ['45.67', '49.45', '52.22']
# (360.7890319824219, 233.74530029296875, 98.64404296875, 175.22821044921875)
# (245.91842651367188, 208.05526733398438, 123.41754150390625, 279.8105773925781)
# (245.91842651367188, 208.05526733398438, 123.41754150390625, 279.8105773925781)
#
# Objects:
# bottle: 60.28%    (left_x: 246   top_y:  210   width:   122   height:  280)
# FPS: 10
# Predicted in 0.09930062294006348 seconds
# ['bottle']
# ['60.28']
# (246.18495178222656, 209.74411010742188, 121.589599609375, 280.22882080078125)
#
# Objects:
# cup: 38.03%    (left_x: 246   top_y:  207   width:   120   height:  283)
# chair: 43.36%    (left_x: 360   top_y:  236   width:   99   height:  177)
# bottle: 76.08%    (left_x: 246   top_y:  207   width:   120   height:  283)
# FPS: 5
# Predicted in 0.19714808464050293 seconds
# ['cup', 'chair', 'bottle']
# ['38.03', '43.36', '76.08']
# (245.9356231689453, 206.63479614257812, 120.43533325195312, 283.2150573730469)
# (360.4540100097656, 235.7920684814453, 98.88497161865234, 177.48912048339844)
# (245.9356231689453, 206.63479614257812, 120.43533325195312, 283.2150573730469)
#
# Objects:
# cup: 58.81%    (left_x: 246   top_y:  207   width:   122   height:  282)
# bottle: 70.4%    (left_x: 246   top_y:  207   width:   122   height:  282)
# FPS: 5
# Predicted in 0.19290971755981445 seconds
# ['cup', 'bottle']
# ['58.81', '70.4']
# (245.88812255859375, 207.2743377685547, 121.8326644897461, 282.4400939941406)
# (245.88812255859375, 207.2743377685547, 121.8326644897461, 282.4400939941406)
#
# Objects:
# chair: 36.99%    (left_x: 360   top_y:  234   width:   99   height:  178)
# cup: 58.31%    (left_x: 246   top_y:  209   width:   123   height:  279)
# bottle: 63.3%    (left_x: 246   top_y:  209   width:   123   height:  279)
# FPS: 5
# Predicted in 0.18798613548278809 seconds
# ['chair', 'cup', 'bottle']
# ['36.99', '58.31', '63.3']
# (360.206787109375, 234.08203125, 98.82888793945312, 177.83154296875)
# (246.16366577148438, 209.04461669921875, 122.52333068847656, 279.4220886230469)
# (246.16366577148438, 209.04461669921875, 122.52333068847656, 279.4220886230469)
#
# Objects:
# cup: 46.88%    (left_x: 247   top_y:  210   width:   123   height:  276)
# bottle: 53.78%    (left_x: 247   top_y:  210   width:   123   height:  276)
# FPS: 6
# Predicted in 0.16193056106567383 seconds
# ['cup', 'bottle']
# ['46.88', '53.78']
# (246.57090759277344, 210.24148559570312, 123.32913208007812, 275.59783935546875)
# (246.57090759277344, 210.24148559570312, 123.32913208007812, 275.59783935546875)
#
# Objects:
# chair: 38.79%    (left_x: 361   top_y:  235   width:   99   height:  175)
# cup: 43.12%    (left_x: 247   top_y:  207   width:   122   height:  280)
# bottle: 53.73%    (left_x: 247   top_y:  207   width:   122   height:  280)
# FPS: 6
# Predicted in 0.1574864387512207 seconds
# ['chair', 'cup', 'bottle']
# ['38.79', '43.12', '53.73']
# (360.68988037109375, 234.88705444335938, 98.87411499023438, 175.17129516601562)
# (246.57078552246094, 206.91107177734375, 122.48538208007812, 279.86151123046875)
# (246.57078552246094, 206.91107177734375, 122.48538208007812, 279.86151123046875)
#
# Objects:
# chair: 37.47%    (left_x: 360   top_y:  234   width:   99   height:  176)
# bottle: 50.45%    (left_x: 246   top_y:  206   width:   121   height:  280)
# cup: 62.17%    (left_x: 246   top_y:  206   width:   121   height:  280)
# FPS: 6
# Predicted in 0.15468215942382812 seconds
# ['chair', 'bottle', 'cup']
# ['37.47', '50.45', '62.17']
# (360.29266357421875, 234.06430053710938, 99.19327545166016, 176.01348876953125)
# (246.32012939453125, 206.04202270507812, 121.16880798339844, 280.3567199707031)
# (246.32012939453125, 206.04202270507812, 121.16880798339844, 280.3567199707031)
#
# Objects:
# cup: 33.6%    (left_x: 246   top_y:  208   width:   123   height:  281)
# bottle: 74.33%    (left_x: 246   top_y:  208   width:   123   height:  281)
# FPS: 6
# Predicted in 0.15150761604309082 seconds
# ['cup', 'bottle']
# ['33.6', '74.33']
# (245.74288940429688, 207.90545654296875, 122.84288024902344, 280.9765625)
# (245.74288940429688, 207.90545654296875, 122.84288024902344, 280.9765625)
#
# Objects:
# chair: 35.98%    (left_x: 360   top_y:  235   width:   99   height:  177)
# bottle: 60.32%    (left_x: 246   top_y:  208   width:   121   height:  277)
# cup: 65.42%    (left_x: 246   top_y:  208   width:   121   height:  277)
# FPS: 6
# Predicted in 0.1519923210144043 seconds
# ['chair', 'bottle', 'cup']
# ['35.98', '60.32', '65.42']
# (360.4571838378906, 234.5126190185547, 98.78781127929688, 176.748291015625)
# (246.177978515625, 207.82412719726562, 120.83894348144531, 277.3351745605469)
# (246.177978515625, 207.82412719726562, 120.83894348144531, 277.3351745605469)
#
# Objects:
# chair: 42.98%    (left_x: 361   top_y:  235   width:   100   height:  176)
# bottle: 43.19%    (left_x: 242   top_y:  231   width:   117   height:  267)
# cup: 46.95%    (left_x: 247   top_y:  211   width:   123   height:  277)
# FPS: 6
# Predicted in 0.16066980361938477 seconds
# ['chair', 'bottle', 'cup']
# ['42.98', '43.19', '46.95']
# (360.8420104980469, 234.58660888671875, 100.31600189208984, 176.3914794921875)
# (242.32887268066406, 230.7230682373047, 116.75702667236328, 266.7936096191406)
# (246.5197296142578, 210.55877685546875, 122.81659698486328, 277.26068115234375)
#
# Objects:
# chair: 33.01%    (left_x: 361   top_y:  235   width:   100   height:  176)
# cup: 37.53%    (left_x: 245   top_y:  207   width:   122   height:  274)
# bottle: 60.88%    (left_x: 245   top_y:  207   width:   122   height:  274)
# FPS: 6
# Predicted in 0.16481399536132812 seconds
# ['chair', 'cup', 'bottle']
# ['33.01', '37.53', '60.88']
# (360.75299072265625, 235.07044982910156, 99.68421936035156, 176.4327392578125)
# (245.42062377929688, 207.12686157226562, 121.85198974609375, 274.3048400878906)
# (245.42062377929688, 207.12686157226562, 121.85198974609375, 274.3048400878906)
#
# Objects:
# chair: 30.02%    (left_x: 361   top_y:  234   width:   99   height:  176)
# cup: 48.59%    (left_x: 246   top_y:  210   width:   122   height:  279)
# bottle: 66.09%    (left_x: 246   top_y:  210   width:   122   height:  279)
# FPS: 6
# Predicted in 0.15832185745239258 seconds
# ['chair', 'cup', 'bottle']
# ['30.02', '48.59', '66.09']
# (360.785400390625, 233.65475463867188, 99.24496459960938, 175.98306274414062)
# (246.31051635742188, 210.01197814941406, 122.24038696289062, 279.1832275390625)
# (246.31051635742188, 210.01197814941406, 122.24038696289062, 279.1832275390625)
#
# Objects:
# cup: 42.08%    (left_x: 245   top_y:  210   width:   123   height:  278)
# bottle: 54.54%    (left_x: 245   top_y:  210   width:   123   height:  278)
# FPS: 6
# Predicted in 0.153029203414917 seconds
# ['cup', 'bottle']
# ['42.08', '54.54']
# (245.04244995117188, 209.85604858398438, 123.15990447998047, 278.105712890625)
# (245.04244995117188, 209.85604858398438, 123.15990447998047, 278.105712890625)
#
# Objects:
# bottle: 48.9%    (left_x: 247   top_y:  207   width:   122   height:  277)
# cup: 57.66%    (left_x: 247   top_y:  207   width:   122   height:  277)
# FPS: 10
# Predicted in 0.09938836097717285 seconds
# ['bottle', 'cup']
# ['48.9', '57.66']
# (246.6004180908203, 206.93760681152344, 121.73332977294922, 276.65667724609375)
# (246.6004180908203, 206.93760681152344, 121.73332977294922, 276.65667724609375)
#
# Objects:
# chair: 39.15%    (left_x: 360   top_y:  234   width:   98   height:  176)
# bottle: 43.83%    (left_x: 246   top_y:  208   width:   123   height:  282)
# cup: 62.35%    (left_x: 246   top_y:  208   width:   123   height:  282)
# FPS: 6
# Predicted in 0.16637372970581055 seconds
# ['chair', 'bottle', 'cup']
# ['39.15', '43.83', '62.35']
# (360.1407470703125, 233.5467071533203, 97.80049133300781, 176.05897521972656)
# (245.9102783203125, 208.01412963867188, 123.00018310546875, 281.99188232421875)
# (245.9102783203125, 208.01412963867188, 123.00018310546875, 281.99188232421875)
#
# Objects:
# cup: 41.8%    (left_x: 246   top_y:  208   width:   124   height:  278)
# chair: 43.21%    (left_x: 361   top_y:  234   width:   99   height:  176)
# bottle: 68.93%    (left_x: 246   top_y:  208   width:   124   height:  278)
# FPS: 5
# Predicted in 0.17964887619018555 seconds
# ['cup', 'chair', 'bottle']
# ['41.8', '43.21', '68.93']
# (245.89898681640625, 207.8855438232422, 123.64656829833984, 277.71820068359375)
# (360.6641845703125, 234.3599853515625, 99.02745056152344, 176.43125915527344)
# (245.89898681640625, 207.8855438232422, 123.64656829833984, 277.71820068359375)
#
# Objects:
# cup: 57.18%    (left_x: 246   top_y:  207   width:   120   height:  278)
# bottle: 65.15%    (left_x: 246   top_y:  207   width:   120   height:  278)
# FPS: 5
# Predicted in 0.18877196311950684 seconds
# ['cup', 'bottle']
# ['57.18', '65.15']
# (245.71090698242188, 207.2726287841797, 120.29826354980469, 277.76336669921875)
# (245.71090698242188, 207.2726287841797, 120.29826354980469, 277.76336669921875)
#
# Objects:
# chair: 38.49%    (left_x: 361   top_y:  235   width:   101   height:  176)
# bottle: 56.64%    (left_x: 246   top_y:  208   width:   123   height:  282)
# cup: 58.38%    (left_x: 246   top_y:  208   width:   123   height:  282)
# FPS: 4
# Predicted in 0.20157337188720703 seconds
# ['chair', 'bottle', 'cup']
# ['38.49', '56.64', '58.38']
# (360.5205993652344, 234.9156951904297, 100.7391128540039, 176.21771240234375)
# (246.2696533203125, 207.59275817871094, 123.34539794921875, 282.4761047363281)
# (246.2696533203125, 207.59275817871094, 123.34539794921875, 282.4761047363281)
#
# Objects:
# chair: 33.09%    (left_x: 361   top_y:  234   width:   100   height:  174)
# bottle: 43.6%    (left_x: 247   top_y:  207   width:   120   height:  284)
# cup: 64.41%    (left_x: 247   top_y:  207   width:   120   height:  284)
# FPS: 6
# Predicted in 0.16037631034851074 seconds
# ['chair', 'bottle', 'cup']
# ['33.09', '43.6', '64.41']
# (360.9013671875, 234.0203094482422, 100.04840087890625, 174.34571838378906)
# (247.3953094482422, 207.12930297851562, 119.86678314208984, 283.6507568359375)
# (247.3953094482422, 207.12930297851562, 119.86678314208984, 283.6507568359375)
#
# Objects:
# cup: 54.41%    (left_x: 247   top_y:  207   width:   122   height:  284)
# bottle: 63.07%    (left_x: 247   top_y:  207   width:   122   height:  284)
# FPS: 6
# Predicted in 0.15454435348510742 seconds
# ['cup', 'bottle']
# ['54.41', '63.07']
# (246.6820526123047, 207.44847106933594, 121.53236389160156, 283.6591491699219)
# (246.6820526123047, 207.44847106933594, 121.53236389160156, 283.6591491699219)
#
# Objects:
# bottle: 51.79%    (left_x: 245   top_y:  210   width:   121   height:  279)
# cup: 66.66%    (left_x: 245   top_y:  210   width:   121   height:  279)
# FPS: 6
# Predicted in 0.15006661415100098 seconds
# ['bottle', 'cup']
# ['51.79', '66.66']
# (245.3591766357422, 209.88812255859375, 120.82672119140625, 278.90155029296875)
# (245.3591766357422, 209.88812255859375, 120.82672119140625, 278.90155029296875)
#
# Objects:
# bottle: 41.63%    (left_x: 245   top_y:  208   width:   122   height:  272)
# cup: 51.37%    (left_x: 245   top_y:  208   width:   122   height:  272)
# FPS: 12
# Predicted in 0.08315420150756836 seconds
# ['bottle', 'cup']
# ['41.63', '51.37']
# (245.4579620361328, 207.94187927246094, 121.94093322753906, 272.02386474609375)
# (245.4579620361328, 207.94187927246094, 121.94093322753906, 272.02386474609375)
#
# Objects:
# cup: 39.31%    (left_x: 246   top_y:  205   width:   125   height:  283)
# bottle: 71.1%    (left_x: 246   top_y:  205   width:   125   height:  283)
# FPS: 12
# Predicted in 0.08305096626281738 seconds
# ['cup', 'bottle']
# ['39.31', '71.1']
# (246.19129943847656, 205.33892822265625, 125.36378479003906, 283.2781066894531)
# (246.19129943847656, 205.33892822265625, 125.36378479003906, 283.2781066894531)
#
# Objects:
# cup: 61.24%    (left_x: 246   top_y:  207   width:   121   height:  278)
# bottle: 71.01%    (left_x: 246   top_y:  207   width:   121   height:  278)
# FPS: 10
# Predicted in 0.09242939949035645 seconds
# ['cup', 'bottle']
# ['61.24', '71.01']
# (245.60565185546875, 207.07069396972656, 120.64888763427734, 277.8025817871094)
# (245.60565185546875, 207.07069396972656, 120.64888763427734, 277.8025817871094)
#
# Objects:
# chair: 50.53%    (left_x: 361   top_y:  234   width:   99   height:  175)
# bottle: 54.54%    (left_x: 246   top_y:  208   width:   119   height:  282)
# cup: 56.6%    (left_x: 246   top_y:  208   width:   119   height:  282)
# FPS: 5
# Predicted in 0.16923975944519043 seconds
# ['chair', 'bottle', 'cup']
# ['50.53', '54.54', '56.6']
# (360.6988830566406, 233.955322265625, 99.33440399169922, 175.4381866455078)
# (245.61334228515625, 207.97006225585938, 119.36833190917969, 281.6492004394531)
# (245.61334228515625, 207.97006225585938, 119.36833190917969, 281.6492004394531)
#
# Objects:

# %% [markdown]
# Cool! We've created our neural network execution function, but now we need to attach it to the camera for processing.
#
# We accomplish that with the observe function.

# %% [markdown]
# >WARNING: This code will move the robot!! Please make sure your robot has clearance and it is on Lego or Track you have collected data on. The road follower should work, but the neural network is only as good as the data it's trained on!

# %%
camera.unobserve(execute, names='value')

time.sleep(0.1)  # add a small sleep to make sure frames have finished processing
camera.stop()
robot.stop()
# Out:
# chair: 33.2%    (left_x: 361   top_y:  234   width:   101   height:  178)
# bottle: 50.02%    (left_x: 244   top_y:  232   width:   120   height:  260)
# cup: 56.66%    (left_x: 246   top_y:  208   width:   122   height:  279)
# FPS: 5
# Predicted in 0.17640423774719238 seconds
# ['chair', 'bottle', 'cup']
# ['33.2', '50.02', '56.66']
# (361.16925048828125, 234.1702423095703, 100.9041748046875, 177.65853881835938)
# (244.392578125, 231.5783233642578, 119.94430541992188, 259.6139831542969)
# (246.1241912841797, 207.84762573242188, 121.73562622070312, 278.83740234375)
#
# Objects:
# cup: 51.28%    (left_x: 246   top_y:  212   width:   126   height:  277)
# bottle: 66.11%    (left_x: 246   top_y:  212   width:   126   height:  277)
# FPS: 6
# Predicted in 0.15590834617614746 seconds
# ['cup', 'bottle']
# ['51.28', '66.11']
# (246.2762451171875, 211.97479248046875, 125.6891098022461, 276.9694519042969)
# (246.2762451171875, 211.97479248046875, 125.6891098022461, 276.9694519042969)

# %%
camera.stop()
robot.stop()
